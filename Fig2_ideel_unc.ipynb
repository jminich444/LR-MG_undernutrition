# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

from scipy.stats import ttest_rel
sns.set(style="whitegrid")

# %%
ls
# Out:
# 30_MAG_Genomes_Query_Hit_Name_Method_042825.csv
# 30_MAG_Genomes_Query_to_Hit_Correlations_042825.csv
# Fig2_ideel.ipynb
# Fig2_ideel.png
# image (3).png

# %%
ideel=pd.read_csv('Table_S10_ideel.csv')

# %%
plt.figure(figsize=(5,5))
colors=["blue","magenta"]
sns.scatterplot(data=ideel, x="query", y="hit", hue="Method", palette=colors, alpha=0.2)
plt.xlabel('Query gene length from cMAG')
plt.ylabel('Database hit gene length')
# Set axis ranges
plt.xlim(0, 8000)   # set x-axis from 0 to 6
plt.ylim(0, 8000) 
plt.savefig("Fig2D_ideel.png", dpi=600, bbox_inches="tight")

# %%
ONT_1_s__Prevotella_sp000436035=ideel.loc[ideel['total']=='ONT_1_s__Prevotella.sp000436035']
ONT_2_s__Prevotella_stercorea=ideel.loc[ideel['total']=='ONT_2_s__Prevotella.stercorea']
ONT_3_s__Campylobacter_D_sp900539255=ideel.loc[ideel['total']=='ONT_3_s__Campylobacter_D.sp900539255']
ONT_4_s__Campylobacter_infans=ideel.loc[ideel['total']=='ONT_4_s__Campylobacter.infans']
ONT_5_s__Zag111_sp002102825=ideel.loc[ideel['total']=='ONT_5_s__Zag111.sp002102825']
ONT_6_s__Agathobacter_sp900543445=ideel.loc[ideel['total']=='ONT_6_s__Agathobacter.sp900543445']
ONT_7_s__Agathobacter_sp900546625=ideel.loc[ideel['total']=='ONT_7_s__Agathobacter.sp900546625']
ONT_8_g__Faecalibacterium_s__=ideel.loc[ideel['total']=='ONT_8_g__Faecalibacterium;s__']
ONT_9_s__Agathobacter_sp900546625=ideel.loc[ideel['total']=='ONT_9_s__Agathobacter.sp900546625']
ONT_10_s__Dialister_sp000434475=ideel.loc[ideel['total']=='ONT_10_s__Dialister.sp000434475']
ONT_11_s__Prevotella_copri_A=ideel.loc[ideel['total']=='ONT_11_s__Prevotella.copri_A']
ONT_12_s__Prevotella_sp002265625=ideel.loc[ideel['total']=='ONT_12_s__Prevotella.sp002265625']
ONT_13_s__Campylobacter_D_sp900539255=ideel.loc[ideel['total']=='ONT_13_s__Campylobacter_D.sp900539255']
ONT_14_s__Zag111_sp002102825=ideel.loc[ideel['total']=='ONT_14_s__Zag111.sp002102825']
ONT_15_s__Agathobacter_faecis=ideel.loc[ideel['total']=='ONT_15_s__Agathobacter.faecis']
PB_1_s__Prevotella_sp000436035=ideel.loc[ideel['total']=='PB_1_s__Prevotella.sp000436035']
PB_2_s__Prevotella_stercorea=ideel.loc[ideel['total']=='PB_2_s__Prevotella.stercorea']
PB_3_s__Campylobacter_D_sp900539255=ideel.loc[ideel['total']=='PB_3_s__Campylobacter_D.sp900539255']
PB_4_s__Campylobacter_infans=ideel.loc[ideel['total']=='PB_4_s__Campylobacter.infans']
PB_5_s__Zag111_sp002102825=ideel.loc[ideel['total']=='PB_5_s__Zag111.sp002102825']
PB_6_s__Agathobacter_sp900543445=ideel.loc[ideel['total']=='PB_6_s__Agathobacter.sp900543445']
PB_7_s__Agathobacter_sp900546625=ideel.loc[ideel['total']=='PB_7_s__Agathobacter.sp900546625']
PB_8_g__Faecalibacterium_s__=ideel.loc[ideel['total']=='PB_8_g__Faecalibacterium;s__']
PB_9_s__Agathobacter_sp900546625=ideel.loc[ideel['total']=='PB_9_s__Agathobacter.sp900546625']
PB_10_s__Dialister_sp000434475=ideel.loc[ideel['total']=='PB_10_s__Dialister.sp000434475']
PB_11_s__Prevotella_copri_A=ideel.loc[ideel['total']=='PB_11_s__Prevotella.copri_A']
PB_12_s__Prevotella_sp002265625=ideel.loc[ideel['total']=='PB_12_s__Prevotella.sp002265625']
PB_13_s__Campylobacter_D_sp900539255=ideel.loc[ideel['total']=='PB_13_s__Campylobacter_D.sp900539255']
PB_14_s__Zag111_sp002102825=ideel.loc[ideel['total']=='PB_14_s__Zag111.sp002102825']
PB_15_s__Agathobacter_faecis=ideel.loc[ideel['total']=='PB_15_s__Agathobacter.faecis']

# %%
r_ONT_1=ONT_1_s__Prevotella_sp000436035['query'].corr(AF4['hit'], method='pearson')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 r_ONT_1=ONT_1_s__Prevotella_sp000436035['query'].corr(AF4['hit'], method='pearson')
#
# NameError: name 'AF4' is not defined

# %%
#calculate pearson R value for each of the 15 genomes assembled from either ONT metaflye or PB metaMDBG
r_ONT_1=ONT_1_s__Prevotella_sp000436035['query'].corr(ONT_1_s__Prevotella_sp000436035['hit'], method='pearson')
r_ONT_2=ONT_2_s__Prevotella_stercorea['query'].corr(ONT_2_s__Prevotella_stercorea['hit'], method='pearson')
r_ONT_3=ONT_3_s__Campylobacter_D_sp900539255['query'].corr(ONT_3_s__Campylobacter_D_sp900539255['hit'], method='pearson')
r_ONT_4=ONT_4_s__Campylobacter_infans['query'].corr(ONT_4_s__Campylobacter_infans['hit'], method='pearson')
r_ONT_5=ONT_5_s__Zag111_sp002102825['query'].corr(ONT_5_s__Zag111_sp002102825['hit'], method='pearson')
r_ONT_6=ONT_6_s__Agathobacter_sp900543445['query'].corr(ONT_6_s__Agathobacter_sp900543445['hit'], method='pearson')
r_ONT_7=ONT_7_s__Agathobacter_sp900546625['query'].corr(ONT_7_s__Agathobacter_sp900546625['hit'], method='pearson')
r_ONT_8=ONT_8_g__Faecalibacterium_s__['query'].corr(ONT_8_g__Faecalibacterium_s__['hit'], method='pearson')
r_ONT_9=ONT_9_s__Agathobacter_sp900546625['query'].corr(ONT_9_s__Agathobacter_sp900546625['hit'], method='pearson')
r_ONT_10=ONT_10_s__Dialister_sp000434475['query'].corr(ONT_10_s__Dialister_sp000434475['hit'], method='pearson')
r_ONT_11=ONT_11_s__Prevotella_copri_A['query'].corr(ONT_11_s__Prevotella_copri_A['hit'], method='pearson')
r_ONT_12=ONT_12_s__Prevotella_sp002265625['query'].corr(ONT_12_s__Prevotella_sp002265625['hit'], method='pearson')
r_ONT_13=ONT_13_s__Campylobacter_D_sp900539255['query'].corr(ONT_13_s__Campylobacter_D_sp900539255['hit'], method='pearson')
r_ONT_14=ONT_14_s__Zag111_sp002102825['query'].corr(ONT_14_s__Zag111_sp002102825['hit'], method='pearson')
r_ONT_15=ONT_15_s__Agathobacter_faecis['query'].corr(ONT_15_s__Agathobacter_faecis['hit'], method='pearson')
r_PB_1=PB_1_s__Prevotella_sp000436035['query'].corr(PB_1_s__Prevotella_sp000436035['hit'], method='pearson')
r_PB_2=PB_2_s__Prevotella_stercorea['query'].corr(PB_2_s__Prevotella_stercorea['hit'], method='pearson')
r_PB_3=PB_3_s__Campylobacter_D_sp900539255['query'].corr(PB_3_s__Campylobacter_D_sp900539255['hit'], method='pearson')
r_PB_4=PB_4_s__Campylobacter_infans['query'].corr(PB_4_s__Campylobacter_infans['hit'], method='pearson')
r_PB_5=PB_5_s__Zag111_sp002102825['query'].corr(PB_5_s__Zag111_sp002102825['hit'], method='pearson')
r_PB_6=PB_6_s__Agathobacter_sp900543445['query'].corr(PB_6_s__Agathobacter_sp900543445['hit'], method='pearson')
r_PB_7=PB_7_s__Agathobacter_sp900546625['query'].corr(PB_7_s__Agathobacter_sp900546625['hit'], method='pearson')
r_PB_8=PB_8_g__Faecalibacterium_s__['query'].corr(PB_8_g__Faecalibacterium_s__['hit'], method='pearson')
r_PB_9=PB_9_s__Agathobacter_sp900546625['query'].corr(PB_9_s__Agathobacter_sp900546625['hit'], method='pearson')
r_PB_10=PB_10_s__Dialister_sp000434475['query'].corr(PB_10_s__Dialister_sp000434475['hit'], method='pearson')
r_PB_11=PB_11_s__Prevotella_copri_A['query'].corr(PB_11_s__Prevotella_copri_A['hit'], method='pearson')
r_PB_12=PB_12_s__Prevotella_sp002265625['query'].corr(PB_12_s__Prevotella_sp002265625['hit'], method='pearson')
r_PB_13=PB_13_s__Campylobacter_D_sp900539255['query'].corr(PB_13_s__Campylobacter_D_sp900539255['hit'], method='pearson')
r_PB_14=PB_14_s__Zag111_sp002102825['query'].corr(PB_14_s__Zag111_sp002102825['hit'], method='pearson')
r_PB_15=PB_15_s__Agathobacter_faecis['query'].corr(PB_15_s__Agathobacter_faecis['hit'], method='pearson')

# %%
#print values
ONT_pearson=[r_ONT_1,
r_ONT_2,
r_ONT_3,
r_ONT_4,
r_ONT_5,
r_ONT_6,
r_ONT_7,
r_ONT_8,
r_ONT_9,
r_ONT_10,
r_ONT_11,
r_ONT_12,
r_ONT_13,
r_ONT_14,
r_ONT_15]

PB_pearson=[r_PB_1,
r_PB_2,
r_PB_3,
r_PB_4,
r_PB_5,
r_PB_6,
r_PB_7,
r_PB_8,
r_PB_9,
r_PB_10,
r_PB_11,
r_PB_12,
r_PB_13,
r_PB_14,
r_PB_15]

# %%
plt.figure(figsize=(2,5))
colors=["blue", "magenta"]
sns.boxplot(data=[ONT_pearson, PB_pearson], palette=colors)
plt.xticks([0, 1], ['ONT metaFlye', 'PB metaMDBG'])  # Set custom x-axis labels
plt.xticks(rotation=45, ha="right")
plt.ylim(0.5, 1)   # set x-axis from 0 to 6

plt.savefig("Fig2E_pearson_.png", dpi=600, bbox_inches="tight")

# %%
# Run a paired T test on the two array values
# Run paired t-test
t_stat, p_value = ttest_rel(ONT_pearson, PB_pearson)

print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: -2.5957757179956995
# p-value: 0.02115048435465298
